# %% [markdown]
# <a href="https://colab.research.google.com/github/Njarrin/ToxicityTestingCapstonenelsonjarrin/blob/main/Perspective_API_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Nelson Jarrin
# **Language**: Python
#
# **API Used**: Google Perspective API
#
# **Original API Documentation**: https://developers.perspectiveapi.com/
#
# **Notebook Inspiration Acknowledgement**:
# This notebook is based on the official documentation and examples provided by Google/Jigsaw for the Perspective API.

# %%
# !pip install pandas google-cloud-storage google-api-python-client
from google.colab import auth
auth.authenticate_user()
from google.cloud import storage
import pandas as pd
from googleapiclient import discovery
import time
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (2.19.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (2.155.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.27.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.19.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.32.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (1.6.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (4.25.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.25.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2024.12.14)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.6.1)

# %%
# 1. Load Data from Google Cloud Storage
try:
    client = storage.Client()
    bucket = client.bucket('datasetforcapstonenelsonjarrin')
    blob = bucket.blob('unhealthy_test.csv')
    df = pd.read_csv(blob.open('r'))
    print("Test data loaded successfully!")
    print(df.head())
    print("Columns in Test DataFrame:", df.columns)
except Exception as e:
    print(f"Error loading DataFrame: {e}")
    exit()
# Out:
# Test data loaded successfully!
#      _unit_id  _trusted_judgments  \
# 0  1739450989                   3
# 1  1739442069                   5
# 2  1739464409                   3
# 3  1739447549                   5
# 4  1739466909                   3
#
#                                              comment  antagonize  \
# 0  When you have Conservative members now feeling...           0
# 1  That's one of the problem, as Germany sent out...           0
# 2  Yesshe is, and if she was always and only refe...           0
# 3  There is nothing honourable about Stephen Harper.           1
# 4  What a pathetic piece of writing. I have no re...           0
#
#    antagonize:confidence  condescending  condescending:confidence  dismissive  \
# 0                 1.0000              0                    1.0000           0
# 1                 0.7955              0                    1.0000           0
# 2                 1.0000              0                    1.0000           0
# 3                 0.6215              0                    0.5787           0
# 4                 1.0000              0                    1.0000           0
#
#    dismissive:confidence  generalisation  generalisation:confidence  \
# 0                 1.0000               0                      1.000
# 1                 1.0000               0                      0.792
# 2                 1.0000               0                      1.000
# 3                 0.5787               0                      1.000
# 4                 1.0000               0                      1.000
#
#    generalisation_unfair  generalisation_unfair:confidence  healthy  \
# 0                    0.0                               1.0        1
# 1                    0.0                               1.0        1
# 2                    0.0                               1.0        1
# 3                    0.0                               1.0        1
# 4                    0.0                               1.0        1
#
#    healthy:confidence  hostile  hostile:confidence  sarcastic  \
# 0              1.0000        0              1.0000          0
# 1              0.7955        0              1.0000          0
# 2              1.0000        0              1.0000          0
# 3              0.5814        0              0.5948          0
# 4              1.0000        0              1.0000          0
#
#    sarcastic:confidence
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Columns in Test DataFrame: Index(['_unit_id', '_trusted_judgments', 'comment', 'antagonize',
#        'antagonize:confidence', 'condescending', 'condescending:confidence',
#        'dismissive', 'dismissive:confidence', 'generalisation',
#        'generalisation:confidence', 'generalisation_unfair',
#        'generalisation_unfair:confidence', 'healthy', 'healthy:confidence',
#        'hostile', 'hostile:confidence', 'sarcastic', 'sarcastic:confidence'],
#       dtype='object')

# %%
# 2. Limit Data for Testing (Optional, but recommended for initial testing)
small_df = df.head(100) #Increased to 100 for more meaningful comparisons

# %%
# 3. Perspective API Setup
API_KEY = "" #hidden, please contact me directly for my API key

def get_perspective_scores(text):
    """
    Calls the Perspective API and returns scores for the given text.

    Args:
        text: The text to analyze.

    Returns:
        A dictionary of scores, or None if there's an error.
    """
    try:
        client = discovery.build(
            "commentanalyzer",
            "v1alpha1",
            developerKey=API_KEY,
            discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
            static_discovery=False,
        )

        analyze_request = {
            'comment': {'text': text},
            'requestedAttributes': {'TOXICITY': {}}  # Requesting only toxicity
        }
        response = client.comments().analyze(body=analyze_request).execute()
        return response['attributeScores']['TOXICITY']['summaryScore']['value'] #Extract the toxicity score
    except Exception as e:
        print(f"Perspective API Error: {e}")
        return None  # Return None to indicate an error

def process_data(df):
    """
    Processes the DataFrame and retrieves Perspective API scores.

    Args:
        df: The DataFrame containing comments.

    Returns:
        A list of toxicity scores from the perspective API.
    """
    perspective_scores = []
    for index, row in df.iterrows():
        text = row['comment'] #Make sure this matches your column name
        score = get_perspective_scores(text)
        perspective_scores.append(score)
        time.sleep(1) #Reduced sleep time for testing
        print(f"Processed row {index}")
    return perspective_scores

# %%
# 4. Process Data and Get Scores
perspective_scores = process_data(small_df)
# Out:
# Processed row 0
# Processed row 1
# Processed row 2
# Processed row 3
# Processed row 4
# Processed row 5
# Processed row 6
# Processed row 7
# Processed row 8
# Processed row 9
# Processed row 10
# Processed row 11
# Processed row 12
# Processed row 13
# Processed row 14
# Processed row 15
# Processed row 16
# Processed row 17
# Processed row 18
# Processed row 19
# Processed row 20
# Processed row 21
# Processed row 22
# Processed row 23
# Processed row 24
# Processed row 25
# Processed row 26
# Processed row 27
# Processed row 28
# Processed row 29
# Processed row 30
# Processed row 31
# Processed row 32
# Processed row 33
# Processed row 34
# Processed row 35
# Processed row 36
# Processed row 37
# Processed row 38
# Processed row 39
# Processed row 40
# Processed row 41
# Processed row 42
# Processed row 43
# Processed row 44
# Processed row 45
# Processed row 46
# Processed row 47
# Processed row 48
# Processed row 49
# Processed row 50
# Processed row 51
# Processed row 52
# Processed row 53
# Processed row 54
# Processed row 55
# Processed row 56
# Processed row 57
# Processed row 58
# Processed row 59
# Processed row 60
# Processed row 61
# Processed row 62
# Processed row 63
# Processed row 64
# Processed row 65
# Processed row 66
# Processed row 67
# Processed row 68
# Processed row 69
# Processed row 70
# Processed row 71
# Processed row 72
# Processed row 73
# Processed row 74
# Processed row 75
# Processed row 76
# Processed row 77
# Processed row 78
# Processed row 79
# Processed row 80
# Processed row 81
# Processed row 82
# Processed row 83
# Processed row 84
# Processed row 85
# Processed row 86
# Processed row 87
# Processed row 88
# Processed row 89
# Processed row 90
# Processed row 91
# Processed row 92
# Processed row 93
# Processed row 94
# Processed row 95
# Processed row 96
# Processed row 97
# Processed row 98
# Processed row 99

# %%
# 5. Create a new dataframe with the scores
perspective_df = pd.DataFrame({'comment': small_df['comment'], 'perspective_toxicity': perspective_scores})

# %%
# 6. Display the Results
print("\nPerspective API Results:")
print(perspective_df)

#Example of how to access the scores
for index, row in perspective_df.iterrows():
    print(f"Comment: {row['comment'][:50]}...")
    print(f"Toxicity Score: {row['perspective_toxicity']}")
    print("-" * 20)
# Out:
# Perspective API Results:
#                                               comment  perspective_toxicity
# 0   When you have Conservative members now feeling...              0.035456
# 1   That's one of the problem, as Germany sent out...              0.110002
# 2   Yesshe is, and if she was always and only refe...              0.036634
# 3   There is nothing honourable about Stephen Harper.              0.178050
# 4   What a pathetic piece of writing. I have no re...              0.751094
# ..                                                ...                   ...
# 95  Perhaps it is time for the Russians to have a ...              0.098722
# 96  I cancelled as well. Want hockey? Go to hockey...              0.027207
# 97      I think the answer to your question is 'yes'.              0.011184
# 98  What happened to the 96 Million dollars thrown...              0.023553
# 99  Certainly Minister Philpott could be making mo...              0.020725
#
# [100 rows x 2 columns]
# Comment: When you have Conservative members now feeling saf...
# Toxicity Score: 0.03545588
# --------------------
# Comment: That's one of the problem, as Germany sent out the...
# Toxicity Score: 0.1100022
# --------------------
# Comment: Yesshe is, and if she was always and only referred...
# Toxicity Score: 0.036634352
# --------------------
# Comment: There is nothing honourable about Stephen Harper....
# Toxicity Score: 0.17805049
# --------------------
# Comment: What a pathetic piece of writing. I have no respec...
# Toxicity Score: 0.7510937
# --------------------
# Comment: Bernie Sanders is the only one telling the truth t...
# Toxicity Score: 0.32236105
# --------------------
# Comment: But you see how a person's rights (to live or to s...
# Toxicity Score: 0.30716252
# --------------------
# Comment: If only Mr Tory wasn't it should read.....
# Toxicity Score: 0.030506283
# --------------------
# Comment: There are plenty of bands that have demonstrated s...
# Toxicity Score: 0.016838523
# --------------------
# Comment: OK, I'll state a simple premise: fossil fuels are ...
# Toxicity Score: 0.11057663
# --------------------
# Comment: Women are not sexually superior to men. They are s...
# Toxicity Score: 0.5566829
# --------------------
# Comment: Hey John, very well written comment... no solution...
# Toxicity Score: 0.007288316
# --------------------
# Comment: Someone with Boogey's level of education can't aff...
# Toxicity Score: 0.24282593
# --------------------
# Comment: What all these have to do with Doug's excellent pi...
# Toxicity Score: 0.031684756
# --------------------
# Comment: I saw Bibi interviewed on CNN yesterday. He is an ...
# Toxicity Score: 0.4014846
# --------------------
# Comment: And falling....
# Toxicity Score: 0.033806015
# --------------------
# Comment: Just like Unions expected favours in return....
# Toxicity Score: 0.01237757
# --------------------
# Comment: P_Smith, for people who never heard anything but p...
# Toxicity Score: 0.043399423
# --------------------
# Comment: How Mr. Harper and upon who's back...
# Toxicity Score: 0.015833238
# --------------------
# Comment: Sheep, it's trump who is trying to kill free speec...
# Toxicity Score: 0.31547862
# --------------------
# Comment: That is a supposition as opposed to the certainty ...
# Toxicity Score: 0.4475325
# --------------------
# Comment: I concur. I served 20 years in peacetime. NOT to b...
# Toxicity Score: 0.025674535
# --------------------
# Comment: Truthops? More like Russian propaganda ops....
# Toxicity Score: 0.11479026
# --------------------
# Comment: There is a man in the United States by the name of...
# Toxicity Score: 0.718943
# --------------------
# Comment: What does that even mean Bob ?!...
# Toxicity Score: 0.021432023
# --------------------
# Comment: Heard of King James? Jacques is French for James....
# Toxicity Score: 0.017466826
# --------------------
# Comment: 'So was everybody else'You almost got that one acr...
# Toxicity Score: 0.31686464
# --------------------
# Comment: And what 'global warming' would you be referring t...
# Toxicity Score: 0.01608456
# --------------------
# Comment: Let's call it like it is: Harper is pandering to r...
# Toxicity Score: 0.47473195
# --------------------
# Comment: Old Banister: I suggest you look up the article in...
# Toxicity Score: 0.0201057
# --------------------
# Comment: You think you are wrong - people are perfectly awa...
# Toxicity Score: 0.075294
# --------------------
# Comment: You assume the alternative to pipelines is oil by ...
# Toxicity Score: 0.27412915
# --------------------
# Comment: I know a great many people who do not believe that...
# Toxicity Score: 0.02873857
# --------------------
# Comment: Well Susan, where do you go from here?...
# Toxicity Score: 0.040183347
# --------------------
# Comment: They can advertise in bars but they still need to ...
# Toxicity Score: 0.10653123
# --------------------
# Comment: Sit down, Stevie....
# Toxicity Score: 0.050821137
# --------------------
# Comment: Okay fascist....
# Toxicity Score: 0.4977744
# --------------------
# Comment: How's Harper's failed pipelines, 8 deficits, two r...
# Toxicity Score: 0.07371122
# --------------------
# Comment: 'the truth will be told then...'Oh, come on! Will ...
# Toxicity Score: 0.017215505
# --------------------
# Comment: In a Democracy that's allowed....
# Toxicity Score: 0.01218908
# --------------------
# Comment: But the thing is that 82% of us DON'T want it. Tha...
# Toxicity Score: 0.011812098
# --------------------
# Comment: Well written analysis of Mulcair. There is too muc...
# Toxicity Score: 0.048842013
# --------------------
# Comment: So you are agreeing with me that Yakabuski is just...
# Toxicity Score: 0.03309893
# --------------------
# Comment: ...and the Arctic ice cap has increased by 29%. Lo...
# Toxicity Score: 0.0069741644
# --------------------
# Comment: By American standards Obama is a radical progressi...
# Toxicity Score: 0.112953395
# --------------------
# Comment: This column serves as an unintended backhand to th...
# Toxicity Score: 0.40614098
# --------------------
# Comment: No. It's not about the Roman Catholic faith. It's ...
# Toxicity Score: 0.04315203
# --------------------
# Comment: miss: right-wingers are viagra-starved wet blanket...
# Toxicity Score: 0.52007306
# --------------------
# Comment: Probably true and very sad. Canada has some stupid...
# Toxicity Score: 0.8460273
# --------------------
# Comment: PP lecturing about respect for democracy is someth...
# Toxicity Score: 0.023788974
# --------------------
# Comment: It is said that the road to disaster is lined by g...
# Toxicity Score: 0.017843807
# --------------------
# Comment: It's typically canadian. Racism behind the compute...
# Toxicity Score: 0.60254884
# --------------------
# Comment: Thats what Comrade Stalin said and Comrade (I mean...
# Toxicity Score: 0.07371122
# --------------------
# Comment: Nonsense. Quebec is special, and deserves special ...
# Toxicity Score: 0.19939905
# --------------------
# Comment: What "treason" was that? Khadr as far as we have b...
# Toxicity Score: 0.07212844
# --------------------
# Comment: Advanced case....
# Toxicity Score: 0.01017851
# --------------------
# Comment: What non-racist and foreign policies do you propos...
# Toxicity Score: 0.13908891
# --------------------
# Comment: The easiest solution is to grow thick skin and kee...
# Toxicity Score: 0.15600902
# --------------------
# Comment: The Liberals have failed Canadians utterly on this...
# Toxicity Score: 0.40891263
# --------------------
# Comment: The no-cost solution: Reject immigration applicant...
# Toxicity Score: 0.1693855
# --------------------
# Comment: Funny thing is, efirla2, Jon StewarT probably woul...
# Toxicity Score: 0.3969567
# --------------------
# Comment: Nominally 5 Liberal, but the BC Liberals are Liber...
# Toxicity Score: 0.02779579
# --------------------
# Comment: the purpose of this op ed is to ensure corporate s...
# Toxicity Score: 0.022964042
# --------------------
# Comment: takes two to tango. Read my recent input to live i...
# Toxicity Score: 0.014702292
# --------------------
# Comment: Permanent revolution = Trotsky....
# Toxicity Score: 0.08004235
# --------------------
# Comment: so the authors want a one party democracy in Canad...
# Toxicity Score: 0.013822667
# --------------------
# Comment: Is this tripe the G&M or the Sun? Sorry, but stand...
# Toxicity Score: 0.05725329
# --------------------
# Comment: He wants his Oxycontin to be free, again!...
# Toxicity Score: 0.11450345
# --------------------
# Comment: How would anyone with any sense of probity appoint...
# Toxicity Score: 0.743089
# --------------------
# Comment: You mean you never heard of the 'highway of heroes...
# Toxicity Score: 0.19694418
# --------------------
# Comment: Agreed! Haven't done it in years. The Grind is the...
# Toxicity Score: 0.17805049
# --------------------
# Comment: Harper did nothing ,like Chretien did before him ,...
# Toxicity Score: 0.029445656
# --------------------
# Comment: '... when natural and man-made disasters are someh...
# Toxicity Score: 0.050821137
# --------------------
# Comment: History has taught us that anyone who compares a s...
# Toxicity Score: 0.40336934
# --------------------
# Comment: Let me see, Harper and the Conservatives, or the d...
# Toxicity Score: 0.1693855
# --------------------
# Comment: Sadly, a vote for Trump is a protest vote by peopl...
# Toxicity Score: 0.23667802
# --------------------
# Comment: Ham: must you always be the one to rain on the par...
# Toxicity Score: 0.03828422
# --------------------
# Comment: The HATER Jack trolling as usual. Dismal handling,...
# Toxicity Score: 0.33587718
# --------------------
# Comment: Wente is popular because she does not lean LeftMos...
# Toxicity Score: 0.123468354
# --------------------
# Comment: One of Saudia Arabia's best allies is Israel....
# Toxicity Score: 0.03545588
# --------------------
# Comment: and look what a mess he made of HIS life ......
# Toxicity Score: 0.25915736
# --------------------
# Comment: What? http://www.nytimes.com/2009/02/27/world/amer...
# Toxicity Score: 0.07371122
# --------------------
# Comment: So he went? What exactly did he do, with time/pass...
# Toxicity Score: 0.02968135
# --------------------
# Comment: What a maroon!...
# Toxicity Score: 0.3974717
# --------------------
# Comment: You left out a very important fact. If the opposit...
# Toxicity Score: 0.016964182
# --------------------
# Comment: Progressives are guided by hatered....
# Toxicity Score: 0.32128486
# --------------------
# Comment: are you kidding. what a facile statement coming fr...
# Toxicity Score: 0.25462922
# --------------------
# Comment: Go to your room!...
# Toxicity Score: 0.11388343
# --------------------
# Comment: Too bad the SC has twisted that into a pretzel....
# Toxicity Score: 0.103494145
# --------------------
# Comment: it's a good song. Really reminds me of the sound M...
# Toxicity Score: 0.02035702
# --------------------
# Comment: He is a former Conservative candidate ......
# Toxicity Score: 0.010681152
# --------------------
# Comment: Will any of your "examples" fix Ontario's tax, def...
# Toxicity Score: 0.014136819
# --------------------
# Comment: Wells aid!...
# Toxicity Score: 0.015519086
# --------------------
# Comment: I agree. Now that I'm older I can't read so well a...
# Toxicity Score: 0.36095104
# --------------------
# Comment: At every level, public health doctors have the aut...
# Toxicity Score: 0.02920996
# --------------------
# Comment: Perhaps it is time for the Russians to have a real...
# Toxicity Score: 0.09872158
# --------------------
# Comment: I cancelled as well. Want hockey? Go to hockeystre...
# Toxicity Score: 0.027206551
# --------------------
# Comment: I think the answer to your question is 'yes'....
# Toxicity Score: 0.011183795
# --------------------
# Comment: What happened to the 96 Million dollars thrown awa...
# Toxicity Score: 0.023553278
# --------------------
# Comment: Certainly Minister Philpott could be making more m...
# Toxicity Score: 0.02072494
# --------------------

# %%
# 7. Save Perspective API Results to CSV
perspective_df.to_csv("perspective_predictions.csv", index=False)
print("Perspective API predictions saved to perspective_predictions.csv")
# Out:
# Perspective API predictions saved to perspective_predictions.csv
